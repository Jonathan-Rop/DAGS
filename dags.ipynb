# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("example").getOrCreate()

# %%
spark.version
# Out:
# '3.5.4'

# %%
df = spark.read.json("world-population-by-country-2020.json")

# %%
display(df)
# Out:
# DataFrame[_corrupt_record: string]

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.show()
#
# File c:\Users\ADMIN\Desktop\Project-Two\my_venv\Lib\site-packages\pyspark\sql\dataframe.py:947, in DataFrame.show(self, n, truncate, vertical)
#     887 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     888     """Prints the first ``n`` rows to the console.
#     889
#     890     .. versionadded:: 1.3.0
#    (...)    945     name | Bob
#     946     """
# --> 947     print(self._show_string(n, truncate, vertical))
#
# File c:\Users\ADMIN\Desktop\Project-Two\my_venv\Lib\site-packages\pyspark\sql\dataframe.py:965, in DataFrame._show_string(self, n, truncate, vertical)
#     959     raise PySparkTypeError(
#     960         error_class="NOT_BOOL",
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
